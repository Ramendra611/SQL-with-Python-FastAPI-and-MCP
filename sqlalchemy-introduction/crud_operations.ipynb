# %%
from models import Author, Book
from database_orm import SessionLocal
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from ..models import Author, Book
#       2 from database_orm import SessionLocal
#
# ImportError: attempted relative import with no known parent package

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 session = SessionLocal()
#       3 # You can add multiple objects at once
#       4 authors = [
#       5     Author(name="Chetan Bhagat", country="India"),
#       6     Author(name="Ruskin Bond", country="India",
#    (...)      9            bio="Author of the Shiva Trilogy"),
#      10 ]
#
# NameError: name 'SessionLocal' is not defined
